# %%
## Import the required python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Weather_Data.csv", parse_dates=['Date/Time'])

# %%
df.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Length: 8784, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                    count                 mean                  min  \
# Date/Time           8784  2012-07-01 23:30:00  2012-01-01 00:00:00
# Temp_C            8784.0             8.798144                -23.3
# Dew Point Temp_C  8784.0             2.555294                -28.5
# Rel Hum_%         8784.0            67.431694                 18.0
# Wind Speed_km/h   8784.0            14.945469                  0.0
# Visibility_km     8784.0            27.664447                  0.2
# Press_kPa         8784.0           101.051623                97.52
#
#                                   25%                  50%  \
# Date/Time         2012-04-01 11:45:00  2012-07-01 23:30:00
# Temp_C                            0.1                  9.3
# Dew Point Temp_C                 -5.9                  3.3
# Rel Hum_%                        56.0                 68.0
# Wind Speed_km/h                   9.0                 13.0
# Visibility_km                    24.1                 25.0
# Press_kPa                      100.56               101.07
#
#                                   75%                  max        std
# Date/Time         2012-10-01 11:15:00  2012-12-31 23:00:00        NaN
# Temp_C                           18.8                 33.0  11.687883
# Dew Point Temp_C                 11.8                 24.4  10.883072
# Rel Hum_%                        81.0                100.0  16.918881
# Wind Speed_km/h                  20.0                 83.0   8.688696
# Visibility_km                    25.0                 48.3  12.622688
# Press_kPa                      101.59               103.65   0.844005

# %%
Q1 = df['Temp_C'].quantile(0.25)

# %%
Q3 = df['Temp_C'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(df)
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Temp_C'])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Dew Point Temp_C'])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Rel Hum_%'])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Wind Speed_km/h'])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Visibility_km'])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.hist(x = df['Press_kPa'])
plt.show()

# %%
plt.figure(figsize = (14, 8))
sns.lineplot(df)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['Year'] = df['Date/Time'].dt.year
df['Months'] = df['Date/Time'].dt.month
df['Day'] = df['Date/Time'].dt.day

# %%
numeric_df = df.select_dtypes(include=[float, int])

# %%
correlation_matrix = numeric_df.corr()

# %%
# print(correlation_matrix)

# %%
plt.figure(figsize = (14, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='cool')
plt.show()
